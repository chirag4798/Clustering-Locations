# %% [markdown]
# <a href="https://www.bigdatauniversity.com"><img src = "https://ibm.box.com/shared/static/cw2c7r3o20w9zn8gkecaeyjhgw3xdgbj.png" width = 400, align = "center"></a>
# # <center>Density-Based Clustering</center>

# %% [markdown]
# Most of the traditional clustering techniques, such as k-means, hierarchical and fuzzy clustering, can be used to group data without supervision.
#
# However, when applied to tasks with arbitrary shape clusters, or clusters within cluster, the traditional techniques might be unable to achieve good results. That is, elements in the same cluster might not share enough similarity or the performance may be poor.
# Additionally, Density-based Clustering locates regions of high density that are separated from one another by regions of low density. Density, in this context, is defined as the number of points within a specified radius.
#
#
#
# In this section, the main focus will be manipulating the data and properties of DBSCAN and observing the resulting clustering.

# %% [markdown]
# Import the following libraries:
# <ul>
#     <li> <b>numpy as np</b> </li>
#     <li> <b>DBSCAN</b> from <b>sklearn.cluster</b> </li>
#     <li> <b>make_blobs</b> from <b>sklearn.datasets.samples_generator</b> </li>
#     <li> <b>StandardScaler</b> from <b>sklearn.preprocessing</b> </li>
#     <li> <b>matplotlib.pyplot as plt</b> </li>
# </ul> <br>
# Remember <b> %matplotlib inline </b> to display plots

# %%
# Notice: For visualization of map, you need basemap package.
# if you dont have basemap install on your machine, you can use the following line to install it
# !conda install -c conda-forge  basemap  matplotlib  -y
# Notice: you maight have to refresh your page and re-run the notebook after installation
# Out:
# Collecting package metadata (current_repodata.json): ...working... done
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: C:\Users\CHIRAG\Anaconda3
#
#   added / updated specs:
#     - basemap
#     - matplotlib
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     basemap-1.3.0              |   py37h7cd9bad_2        15.2 MB  conda-forge
#     cycler-0.10.0              |             py_2           9 KB  conda-forge
#     geos-3.8.1                 |       he025d50_0         1.0 MB  conda-forge
#     intel-openmp-2020.0        |              166         1.5 MB
#     kiwisolver-1.2.0           |   py37heaa310e_0          61 KB  conda-forge
#     krb5-1.17.1                |       hc04afaa_0         709 KB
#     libblas-3.8.0              |           15_mkl         3.5 MB  conda-forge
#     libcblas-3.8.0             |           15_mkl         3.5 MB  conda-forge
#     libcurl-7.69.1             |       h1dcc11c_0         276 KB  conda-forge
#     liblapack-3.8.0            |           15_mkl         3.5 MB  conda-forge
#     libssh2-1.8.2              |       h642c060_2         186 KB  conda-forge
#     matplotlib-3.2.1           |                0           6 KB  conda-forge
#     matplotlib-base-3.2.1      |   py37h911224e_0         7.1 MB  conda-forge
#     mkl-2020.0                 |              166        98.9 MB
#     numpy-1.18.1               |   py37h90d3380_1         4.7 MB  conda-forge
#     proj-7.0.0                 |       haa36216_3         2.3 MB  conda-forge
#     pyproj-2.6.0               |   py37he833962_1         330 KB  conda-forge
#     pyshp-2.1.0                |             py_0          31 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:       143.1 MB
#
# The following NEW packages will be INSTALLED:
#
#   basemap            conda-forge/win-64::basemap-1.3.0-py37h7cd9bad_2
#   cycler             conda-forge/noarch::cycler-0.10.0-py_2
#   geos               conda-forge/win-64::geos-3.8.1-he025d50_0
#   intel-openmp       pkgs/main/win-64::intel-openmp-2020.0-166
#   kiwisolver         conda-forge/win-64::kiwisolver-1.2.0-py37heaa310e_0
#   krb5               pkgs/main/win-64::krb5-1.17.1-hc04afaa_0
#   libblas            conda-forge/win-64::libblas-3.8.0-15_mkl
#   libcblas           conda-forge/win-64::libcblas-3.8.0-15_mkl
#   libcurl            conda-forge/win-64::libcurl-7.69.1-h1dcc11c_0
#   liblapack          conda-forge/win-64::liblapack-3.8.0-15_mkl
#   libssh2            conda-forge/win-64::libssh2-1.8.2-h642c060_2
#   matplotlib         conda-forge/win-64::matplotlib-3.2.1-0
#   matplotlib-base    conda-forge/win-64::matplotlib-base-3.2.1-py37h911224e_0
#   mkl                pkgs/main/win-64::mkl-2020.0-166
#   numpy              conda-forge/win-64::numpy-1.18.1-py37h90d3380_1
#   proj               conda-forge/win-64::proj-7.0.0-haa36216_3
#   pyproj             conda-forge/win-64::pyproj-2.6.0-py37he833962_1
#   pyshp              conda-forge/noarch::pyshp-2.1.0-py_0
#
#
#
# Downloading and Extracting Packages
#
# libblas-3.8.0        | 3.5 MB    |            |   0%
# libblas-3.8.0        | 3.5 MB    |            |   0%
# libblas-3.8.0        | 3.5 MB    | 1          |   1%
# libblas-3.8.0        | 3.5 MB    | 1          |   2%
# libblas-3.8.0        | 3.5 MB    | 3          |   3%
# libblas-3.8.0        | 3.5 MB    | 4          |   5%
# libblas-3.8.0        | 3.5 MB    | 7          |   7%
# libblas-3.8.0        | 3.5 MB    | #          |  11%
# libblas-3.8.0        | 3.5 MB    | #7         |  18%
# libblas-3.8.0        | 3.5 MB    | ##         |  20%
# libblas-3.8.0        | 3.5 MB    | ##2        |  23%
# libblas-3.8.0        | 3.5 MB    | ##5        |  25%
# libblas-3.8.0        | 3.5 MB    | ##8        |  28%
# libblas-3.8.0        | 3.5 MB    | ###        |  31%
# libblas-3.8.0        | 3.5 MB    | ###3       |  33%
# libblas-3.8.0        | 3.5 MB    | ###5       |  36%
# libblas-3.8.0        | 3.5 MB    | ###8       |  39%
# libblas-3.8.0        | 3.5 MB    | ####1      |  41%
# libblas-3.8.0        | 3.5 MB    | ####4      |  44%
# libblas-3.8.0        | 3.5 MB    | ####7      |  47%
# libblas-3.8.0        | 3.5 MB    | ####9      |  50%
# libblas-3.8.0        | 3.5 MB    | #####2     |  52%
# libblas-3.8.0        | 3.5 MB    | #####5     |  55%
# libblas-3.8.0        | 3.5 MB    | #####7     |  57%
# libblas-3.8.0        | 3.5 MB    | #####9     |  59%
# libblas-3.8.0        | 3.5 MB    | ######2    |  63%
# libblas-3.8.0        | 3.5 MB    | ######5    |  66%
# libblas-3.8.0        | 3.5 MB    | ######8    |  68%
# libblas-3.8.0        | 3.5 MB    | #######    |  71%
# libblas-3.8.0        | 3.5 MB    | #######2   |  73%
# libblas-3.8.0        | 3.5 MB    | #######4   |  74%
# libblas-3.8.0        | 3.5 MB    | #######9   |  80%
# libblas-3.8.0        | 3.5 MB    | ########2  |  82%
# libblas-3.8.0        | 3.5 MB    | ########4  |  85%
# libblas-3.8.0        | 3.5 MB    | ########6  |  87%
# libblas-3.8.0        | 3.5 MB    | ########8  |  89%
# libblas-3.8.0        | 3.5 MB    | #########  |  90%
# libblas-3.8.0        | 3.5 MB    | #########2 |  93%
# libblas-3.8.0        | 3.5 MB    | #########4 |  94%
# libblas-3.8.0        | 3.5 MB    | #########6 |  96%
# libblas-3.8.0        | 3.5 MB    | #########7 |  97%
# libblas-3.8.0        | 3.5 MB    | #########8 |  99%
# libblas-3.8.0        | 3.5 MB    | ########## | 100%
#
# libcblas-3.8.0       | 3.5 MB    |            |   0%
# libcblas-3.8.0       | 3.5 MB    |            |   0%
# libcblas-3.8.0       | 3.5 MB    | 1          |   1%
# libcblas-3.8.0       | 3.5 MB    | 1          |   2%
# libcblas-3.8.0       | 3.5 MB    | 2          |   3%
# libcblas-3.8.0       | 3.5 MB    | 3          |   4%
# libcblas-3.8.0       | 3.5 MB    | 4          |   5%
# libcblas-3.8.0       | 3.5 MB    | 5          |   5%
# libcblas-3.8.0       | 3.5 MB    | 6          |   7%
# libcblas-3.8.0       | 3.5 MB    | #1         |  11%
# libcblas-3.8.0       | 3.5 MB    | #2         |  12%
# libcblas-3.8.0       | 3.5 MB    | #4         |  15%
# libcblas-3.8.0       | 3.5 MB    | #5         |  16%
# libcblas-3.8.0       | 3.5 MB    | #7         |  17%
# libcblas-3.8.0       | 3.5 MB    | #8         |  19%
# libcblas-3.8.0       | 3.5 MB    | ##         |  20%
# libcblas-3.8.0       | 3.5 MB    | ##2        |  22%
# libcblas-3.8.0       | 3.5 MB    | ##3        |  24%
# libcblas-3.8.0       | 3.5 MB    | ##9        |  30%
# libcblas-3.8.0       | 3.5 MB    | ###2       |  32%
# libcblas-3.8.0       | 3.5 MB    | ###4       |  34%
# libcblas-3.8.0       | 3.5 MB    | ###6       |  36%
# libcblas-3.8.0       | 3.5 MB    | ###7       |  38%
# libcblas-3.8.0       | 3.5 MB    | ###9       |  40%
# libcblas-3.8.0       | 3.5 MB    | ####1      |  42%
# libcblas-3.8.0       | 3.5 MB    | ####3      |  44%
# libcblas-3.8.0       | 3.5 MB    | ####6      |  46%
# libcblas-3.8.0       | 3.5 MB    | ####8      |  48%
# libcblas-3.8.0       | 3.5 MB    | ####9      |  50%
# libcblas-3.8.0       | 3.5 MB    | #####2     |  52%
# libcblas-3.8.0       | 3.5 MB    | #####4     |  54%
# libcblas-3.8.0       | 3.5 MB    | #####6     |  56%
# libcblas-3.8.0       | 3.5 MB    | #####8     |  58%
# libcblas-3.8.0       | 3.5 MB    | #####9     |  59%
# libcblas-3.8.0       | 3.5 MB    | ######     |  61%
# libcblas-3.8.0       | 3.5 MB    | ######2    |  63%
# libcblas-3.8.0       | 3.5 MB    | ######3    |  64%
# libcblas-3.8.0       | 3.5 MB    | ######5    |  65%
# libcblas-3.8.0       | 3.5 MB    | ######7    |  68%
# libcblas-3.8.0       | 3.5 MB    | #######    |  70%
# libcblas-3.8.0       | 3.5 MB    | #######1   |  72%
# libcblas-3.8.0       | 3.5 MB    | #######4   |  74%
# libcblas-3.8.0       | 3.5 MB    | #######6   |  76%
# libcblas-3.8.0       | 3.5 MB    | #######7   |  78%
# libcblas-3.8.0       | 3.5 MB    | ########   |  80%
# libcblas-3.8.0       | 3.5 MB    | ########1  |  82%
# libcblas-3.8.0       | 3.5 MB    | ########3  |  84%
# libcblas-3.8.0       | 3.5 MB    | ########5  |  85%
# libcblas-3.8.0       | 3.5 MB    | ########7  |  87%
# libcblas-3.8.0       | 3.5 MB    | #########  |  90%
# libcblas-3.8.0       | 3.5 MB    | #########2 |  92%
# libcblas-3.8.0       | 3.5 MB    | #########4 |  95%
# libcblas-3.8.0       | 3.5 MB    | #########6 |  96%
# libcblas-3.8.0       | 3.5 MB    | #########8 |  98%
# libcblas-3.8.0       | 3.5 MB    | ########## | 100%
#
# libcurl-7.69.1       | 276 KB    |            |   0%
# libcurl-7.69.1       | 276 KB    | 5          |   6%
# libcurl-7.69.1       | 276 KB    | ##3        |  23%
# libcurl-7.69.1       | 276 KB    | ####6      |  46%
# libcurl-7.69.1       | 276 KB    | ######9    |  70%
# libcurl-7.69.1       | 276 KB    | #########2 |  93%
# libcurl-7.69.1       | 276 KB    | ########## | 100%
#
# libssh2-1.8.2        | 186 KB    |            |   0%
# libssh2-1.8.2        | 186 KB    | 8          |   9%
# libssh2-1.8.2        | 186 KB    | ###4       |  34%
# libssh2-1.8.2        | 186 KB    | ######     |  60%
# libssh2-1.8.2        | 186 KB    | #########4 |  94%
# libssh2-1.8.2        | 186 KB    | ########## | 100%
#
# pyproj-2.6.0         | 330 KB    |            |   0%
# pyproj-2.6.0         | 330 KB    | 4          |   5%
# pyproj-2.6.0         | 330 KB    | ##9        |  29%
# pyproj-2.6.0         | 330 KB    | #####3     |  53%
# pyproj-2.6.0         | 330 KB    | ########2  |  83%
# pyproj-2.6.0         | 330 KB    | ########## | 100%
#
# kiwisolver-1.2.0     | 61 KB     |            |   0%
# kiwisolver-1.2.0     | 61 KB     | ##6        |  26%
# kiwisolver-1.2.0     | 61 KB     | ########## | 100%
#
# cycler-0.10.0        | 9 KB      |            |   0%
# cycler-0.10.0        | 9 KB      | ########## | 100%
#
# geos-3.8.1           | 1.0 MB    |            |   0%
# geos-3.8.1           | 1.0 MB    | 1          |   1%
# geos-3.8.1           | 1.0 MB    | 8          |   9%
# geos-3.8.1           | 1.0 MB    | #1         |  12%
# geos-3.8.1           | 1.0 MB    | #4         |  15%
# geos-3.8.1           | 1.0 MB    | #9         |  19%
# geos-3.8.1           | 1.0 MB    | ##5        |  25%
# geos-3.8.1           | 1.0 MB    | ###2       |  33%
# geos-3.8.1           | 1.0 MB    | ####1      |  42%
# geos-3.8.1           | 1.0 MB    | #####      |  51%
# geos-3.8.1           | 1.0 MB    | ######1    |  61%
# geos-3.8.1           | 1.0 MB    | ######8    |  69%
# geos-3.8.1           | 1.0 MB    | #######6   |  76%
# geos-3.8.1           | 1.0 MB    | ########3  |  84%
# geos-3.8.1           | 1.0 MB    | #########2 |  93%
# geos-3.8.1           | 1.0 MB    | ########## | 100%
#
# krb5-1.17.1          | 709 KB    |            |   0%
# krb5-1.17.1          | 709 KB    | 2          |   2%
# krb5-1.17.1          | 709 KB    | 9          |   9%
# krb5-1.17.1          | 709 KB    | #8         |  18%
# krb5-1.17.1          | 709 KB    | ##4        |  25%
# krb5-1.17.1          | 709 KB    | ###8       |  38%
# krb5-1.17.1          | 709 KB    | #####6     |  56%
# krb5-1.17.1          | 709 KB    | #######2   |  72%
# krb5-1.17.1          | 709 KB    | ########8  |  88%
# krb5-1.17.1          | 709 KB    | ########## | 100%
#
# numpy-1.18.1         | 4.7 MB    |            |   0%
# numpy-1.18.1         | 4.7 MB    |            |   0%
# numpy-1.18.1         | 4.7 MB    | 2          |   3%
# numpy-1.18.1         | 4.7 MB    | 4          |   4%
# numpy-1.18.1         | 4.7 MB    | 6          |   7%
# numpy-1.18.1         | 4.7 MB    | 8          |   9%
# numpy-1.18.1         | 4.7 MB    | #          |  11%
# numpy-1.18.1         | 4.7 MB    | #3         |  14%
# numpy-1.18.1         | 4.7 MB    | #5         |  15%
# numpy-1.18.1         | 4.7 MB    | #7         |  18%
# numpy-1.18.1         | 4.7 MB    | ##         |  20%
# numpy-1.18.1         | 4.7 MB    | ##2        |  22%
# numpy-1.18.1         | 4.7 MB    | ##4        |  24%
# numpy-1.18.1         | 4.7 MB    | ##6        |  26%
# numpy-1.18.1         | 4.7 MB    | ##9        |  30%
# numpy-1.18.1         | 4.7 MB    | ###1       |  32%
# numpy-1.18.1         | 4.7 MB    | ###4       |  34%
# numpy-1.18.1         | 4.7 MB    | ###6       |  36%
# numpy-1.18.1         | 4.7 MB    | ###8       |  38%
# numpy-1.18.1         | 4.7 MB    | ####4      |  44%
# numpy-1.18.1         | 4.7 MB    | ####7      |  47%
# numpy-1.18.1         | 4.7 MB    | ####9      |  49%
# numpy-1.18.1         | 4.7 MB    | #####1     |  52%
# numpy-1.18.1         | 4.7 MB    | #####3     |  54%
# numpy-1.18.1         | 4.7 MB    | #####6     |  56%
# numpy-1.18.1         | 4.7 MB    | #####8     |  59%
# numpy-1.18.1         | 4.7 MB    | ######     |  61%
# numpy-1.18.1         | 4.7 MB    | ######2    |  63%
# numpy-1.18.1         | 4.7 MB    | ######4    |  65%
# numpy-1.18.1         | 4.7 MB    | ######6    |  67%
# numpy-1.18.1         | 4.7 MB    | ######8    |  69%
# numpy-1.18.1         | 4.7 MB    | #######    |  70%
# numpy-1.18.1         | 4.7 MB    | #######2   |  73%
# numpy-1.18.1         | 4.7 MB    | #######5   |  75%
# numpy-1.18.1         | 4.7 MB    | #######7   |  78%
# numpy-1.18.1         | 4.7 MB    | #######9   |  80%
# numpy-1.18.1         | 4.7 MB    | ########2  |  82%
# numpy-1.18.1         | 4.7 MB    | ########4  |  84%
# numpy-1.18.1         | 4.7 MB    | ########6  |  87%
# numpy-1.18.1         | 4.7 MB    | ########8  |  89%
# numpy-1.18.1         | 4.7 MB    | #########1 |  91%
# numpy-1.18.1         | 4.7 MB    | #########3 |  93%
# numpy-1.18.1         | 4.7 MB    | #########5 |  95%
# numpy-1.18.1         | 4.7 MB    | #########7 |  98%
# numpy-1.18.1         | 4.7 MB    | #########9 |  99%
# numpy-1.18.1         | 4.7 MB    | ########## | 100%
#
# basemap-1.3.0        | 15.2 MB   |            |   0%
# basemap-1.3.0        | 15.2 MB   |            |   0%
# basemap-1.3.0        | 15.2 MB   |            |   0%
# basemap-1.3.0        | 15.2 MB   | 1          |   2%
# basemap-1.3.0        | 15.2 MB   | 2          |   2%
# basemap-1.3.0        | 15.2 MB   | 3          |   3%
# basemap-1.3.0        | 15.2 MB   | 3          |   4%
# basemap-1.3.0        | 15.2 MB   | 4          |   4%
# basemap-1.3.0        | 15.2 MB   | 4          |   5%
# basemap-1.3.0        | 15.2 MB   | 5          |   5%
# basemap-1.3.0        | 15.2 MB   | 5          |   6%
# basemap-1.3.0        | 15.2 MB   | 6          |   6%
# basemap-1.3.0        | 15.2 MB   | 7          |   7%
# basemap-1.3.0        | 15.2 MB   | 7          |   7%
# basemap-1.3.0        | 15.2 MB   | 9          |   9%
# basemap-1.3.0        | 15.2 MB   | 9          |  10%
# basemap-1.3.0        | 15.2 MB   | #1         |  11%
# basemap-1.3.0        | 15.2 MB   | #2         |  13%
# basemap-1.3.0        | 15.2 MB   | #3         |  13%
# basemap-1.3.0        | 15.2 MB   | #4         |  15%
# basemap-1.3.0        | 15.2 MB   | #5         |  15%
# basemap-1.3.0        | 15.2 MB   | #5         |  16%
# basemap-1.3.0        | 15.2 MB   | #7         |  17%
# basemap-1.3.0        | 15.2 MB   | #7         |  18%
# basemap-1.3.0        | 15.2 MB   | #8         |  18%
# basemap-1.3.0        | 15.2 MB   | #9         |  19%
# basemap-1.3.0        | 15.2 MB   | #9         |  20%
# basemap-1.3.0        | 15.2 MB   | ##         |  21%
# basemap-1.3.0        | 15.2 MB   | ##1        |  21%
# basemap-1.3.0        | 15.2 MB   | ##2        |  23%
# basemap-1.3.0        | 15.2 MB   | ##3        |  23%
# basemap-1.3.0        | 15.2 MB   | ##3        |  24%
# basemap-1.3.0        | 15.2 MB   | ##4        |  24%
# basemap-1.3.0        | 15.2 MB   | ##4        |  25%
# basemap-1.3.0        | 15.2 MB   | ##5        |  25%
# basemap-1.3.0        | 15.2 MB   | ##5        |  26%
# basemap-1.3.0        | 15.2 MB   | ##6        |  26%
# basemap-1.3.0        | 15.2 MB   | ##6        |  27%
# basemap-1.3.0        | 15.2 MB   | ##7        |  27%
# basemap-1.3.0        | 15.2 MB   | ##7        |  28%
# basemap-1.3.0        | 15.2 MB   | ##7        |  28%
# basemap-1.3.0        | 15.2 MB   | ##8        |  28%
# basemap-1.3.0        | 15.2 MB   | ##8        |  29%
# basemap-1.3.0        | 15.2 MB   | ##8        |  29%
# basemap-1.3.0        | 15.2 MB   | ##9        |  29%
# basemap-1.3.0        | 15.2 MB   | ##9        |  29%
# basemap-1.3.0        | 15.2 MB   | ##9        |  30%
# basemap-1.3.0        | 15.2 MB   | ##9        |  30%
# basemap-1.3.0        | 15.2 MB   | ###        |  30%
# basemap-1.3.0        | 15.2 MB   | ###        |  30%
# basemap-1.3.0        | 15.2 MB   | ###        |  30%
# basemap-1.3.0        | 15.2 MB   | ###        |  31%
# basemap-1.3.0        | 15.2 MB   | ###        |  31%
# basemap-1.3.0        | 15.2 MB   | ###1       |  31%
# basemap-1.3.0        | 15.2 MB   | ###1       |  32%
# basemap-1.3.0        | 15.2 MB   | ###1       |  32%
# basemap-1.3.0        | 15.2 MB   | ###2       |  32%
# basemap-1.3.0        | 15.2 MB   | ###2       |  32%
# basemap-1.3.0        | 15.2 MB   | ###2       |  32%
# basemap-1.3.0        | 15.2 MB   | ###2       |  33%
# basemap-1.3.0        | 15.2 MB   | ###2       |  33%
# basemap-1.3.0        | 15.2 MB   | ###2       |  33%
# basemap-1.3.0        | 15.2 MB   | ###2       |  33%
# basemap-1.3.0        | 15.2 MB   | ###3       |  33%
# basemap-1.3.0        | 15.2 MB   | ###3       |  34%
# basemap-1.3.0        | 15.2 MB   | ###3       |  34%
# basemap-1.3.0        | 15.2 MB   | ###3       |  34%
# basemap-1.3.0        | 15.2 MB   | ###4       |  34%
# basemap-1.3.0        | 15.2 MB   | ###4       |  34%
# basemap-1.3.0        | 15.2 MB   | ###4       |  35%
# basemap-1.3.0        | 15.2 MB   | ###4       |  35%
# basemap-1.3.0        | 15.2 MB   | ###4       |  35%
# basemap-1.3.0        | 15.2 MB   | ###5       |  35%
# basemap-1.3.0        | 15.2 MB   | ###5       |  35%
# basemap-1.3.0        | 15.2 MB   | ###5       |  36%
# basemap-1.3.0        | 15.2 MB   | ###5       |  36%
# basemap-1.3.0        | 15.2 MB   | ###6       |  36%
# basemap-1.3.0        | 15.2 MB   | ###6       |  36%
# basemap-1.3.0        | 15.2 MB   | ###6       |  36%
# basemap-1.3.0        | 15.2 MB   | ###6       |  37%
# basemap-1.3.0        | 15.2 MB   | ###6       |  37%
# basemap-1.3.0        | 15.2 MB   | ###7       |  37%
# basemap-1.3.0        | 15.2 MB   | ###7       |  37%
# basemap-1.3.0        | 15.2 MB   | ###7       |  37%
# basemap-1.3.0        | 15.2 MB   | ###7       |  38%
# basemap-1.3.0        | 15.2 MB   | ###7       |  38%
# basemap-1.3.0        | 15.2 MB   | ###8       |  38%
# basemap-1.3.0        | 15.2 MB   | ###8       |  38%
# basemap-1.3.0        | 15.2 MB   | ###8       |  38%
# basemap-1.3.0        | 15.2 MB   | ###8       |  38%
# basemap-1.3.0        | 15.2 MB   | ###8       |  39%
# basemap-1.3.0        | 15.2 MB   | ###8       |  39%
# basemap-1.3.0        | 15.2 MB   | ###9       |  39%
# basemap-1.3.0        | 15.2 MB   | ###9       |  39%
# basemap-1.3.0        | 15.2 MB   | ###9       |  40%
# basemap-1.3.0        | 15.2 MB   | ###9       |  40%
# basemap-1.3.0        | 15.2 MB   | ###9       |  40%
# basemap-1.3.0        | 15.2 MB   | ####       |  40%
# basemap-1.3.0        | 15.2 MB   | ####       |  40%
# basemap-1.3.0        | 15.2 MB   | ####       |  41%
# basemap-1.3.0        | 15.2 MB   | ####       |  41%
# basemap-1.3.0        | 15.2 MB   | ####       |  41%
# basemap-1.3.0        | 15.2 MB   | ####1      |  41%
# basemap-1.3.0        | 15.2 MB   | ####1      |  41%
# basemap-1.3.0        | 15.2 MB   | ####1      |  42%
# basemap-1.3.0        | 15.2 MB   | ####1      |  42%
# basemap-1.3.0        | 15.2 MB   | ####2      |  42%
# basemap-1.3.0        | 15.2 MB   | ####2      |  42%
# basemap-1.3.0        | 15.2 MB   | ####2      |  42%
# basemap-1.3.0        | 15.2 MB   | ####2      |  43%
# basemap-1.3.0        | 15.2 MB   | ####2      |  43%
# basemap-1.3.0        | 15.2 MB   | ####3      |  43%
# basemap-1.3.0        | 15.2 MB   | ####3      |  43%
# basemap-1.3.0        | 15.2 MB   | ####3      |  44%
# basemap-1.3.0        | 15.2 MB   | ####4      |  44%
# basemap-1.3.0        | 15.2 MB   | ####4      |  44%
# basemap-1.3.0        | 15.2 MB   | ####4      |  44%
# basemap-1.3.0        | 15.2 MB   | ####4      |  45%
# basemap-1.3.0        | 15.2 MB   | ####4      |  45%
# basemap-1.3.0        | 15.2 MB   | ####5      |  45%
# basemap-1.3.0        | 15.2 MB   | ####5      |  46%
# basemap-1.3.0        | 15.2 MB   | ####5      |  46%
# basemap-1.3.0        | 15.2 MB   | ####6      |  46%
# basemap-1.3.0        | 15.2 MB   | ####6      |  47%
# basemap-1.3.0        | 15.2 MB   | ####7      |  47%
# basemap-1.3.0        | 15.2 MB   | ####7      |  47%
# basemap-1.3.0        | 15.2 MB   | ####7      |  48%
# basemap-1.3.0        | 15.2 MB   | ####8      |  48%
# basemap-1.3.0        | 15.2 MB   | ####8      |  48%
# basemap-1.3.0        | 15.2 MB   | ####8      |  49%
# basemap-1.3.0        | 15.2 MB   | ####9      |  49%
# basemap-1.3.0        | 15.2 MB   | ####9      |  49%
# basemap-1.3.0        | 15.2 MB   | ####9      |  50%
# basemap-1.3.0        | 15.2 MB   | #####      |  50%
# basemap-1.3.0        | 15.2 MB   | #####      |  51%
# basemap-1.3.0        | 15.2 MB   | #####1     |  51%
# basemap-1.3.0        | 15.2 MB   | #####1     |  51%
# basemap-1.3.0        | 15.2 MB   | #####1     |  52%
# basemap-1.3.0        | 15.2 MB   | #####2     |  52%
# basemap-1.3.0        | 15.2 MB   | #####2     |  53%
# basemap-1.3.0        | 15.2 MB   | #####2     |  53%
# basemap-1.3.0        | 15.2 MB   | #####3     |  53%
# basemap-1.3.0        | 15.2 MB   | #####3     |  54%
# basemap-1.3.0        | 15.2 MB   | #####4     |  54%
# basemap-1.3.0        | 15.2 MB   | #####4     |  54%
# basemap-1.3.0        | 15.2 MB   | #####4     |  55%
# basemap-1.3.0        | 15.2 MB   | #####5     |  55%
# basemap-1.3.0        | 15.2 MB   | #####5     |  56%
# basemap-1.3.0        | 15.2 MB   | #####5     |  56%
# basemap-1.3.0        | 15.2 MB   | #####6     |  56%
# basemap-1.3.0        | 15.2 MB   | #####6     |  57%
# basemap-1.3.0        | 15.2 MB   | #####6     |  57%
# basemap-1.3.0        | 15.2 MB   | #####7     |  57%
# basemap-1.3.0        | 15.2 MB   | #####7     |  57%
# basemap-1.3.0        | 15.2 MB   | #####7     |  58%
# basemap-1.3.0        | 15.2 MB   | #####8     |  58%
# basemap-1.3.0        | 15.2 MB   | #####8     |  58%
# basemap-1.3.0        | 15.2 MB   | #####8     |  59%
# basemap-1.3.0        | 15.2 MB   | #####9     |  59%
# basemap-1.3.0        | 15.2 MB   | #####9     |  59%
# basemap-1.3.0        | 15.2 MB   | #####9     |  60%
# basemap-1.3.0        | 15.2 MB   | #####9     |  60%
# basemap-1.3.0        | 15.2 MB   | ######     |  60%
# basemap-1.3.0        | 15.2 MB   | ######     |  61%
# basemap-1.3.0        | 15.2 MB   | ######     |  61%
# basemap-1.3.0        | 15.2 MB   | ######1    |  61%
# basemap-1.3.0        | 15.2 MB   | ######1    |  62%
# basemap-1.3.0        | 15.2 MB   | ######1    |  62%
# basemap-1.3.0        | 15.2 MB   | ######2    |  62%
# basemap-1.3.0        | 15.2 MB   | ######2    |  63%
# basemap-1.3.0        | 15.2 MB   | ######2    |  63%
# basemap-1.3.0        | 15.2 MB   | ######3    |  63%
# basemap-1.3.0        | 15.2 MB   | ######3    |  64%
# basemap-1.3.0        | 15.2 MB   | ######3    |  64%
# basemap-1.3.0        | 15.2 MB   | ######4    |  64%
# basemap-1.3.0        | 15.2 MB   | ######4    |  65%
# basemap-1.3.0        | 15.2 MB   | ######4    |  65%
# basemap-1.3.0        | 15.2 MB   | ######5    |  65%
# basemap-1.3.0        | 15.2 MB   | ######5    |  65%
# basemap-1.3.0        | 15.2 MB   | ######5    |  66%
# basemap-1.3.0        | 15.2 MB   | ######6    |  66%
# basemap-1.3.0        | 15.2 MB   | ######6    |  67%
# basemap-1.3.0        | 15.2 MB   | ######6    |  67%
# basemap-1.3.0        | 15.2 MB   | ######7    |  67%
# basemap-1.3.0        | 15.2 MB   | ######7    |  68%
# basemap-1.3.0        | 15.2 MB   | ######7    |  68%
# basemap-1.3.0        | 15.2 MB   | ######8    |  68%
# basemap-1.3.0        | 15.2 MB   | ######8    |  69%
# basemap-1.3.0        | 15.2 MB   | ######8    |  69%
# basemap-1.3.0        | 15.2 MB   | ######9    |  69%
# basemap-1.3.0        | 15.2 MB   | ######9    |  69%
# basemap-1.3.0        | 15.2 MB   | ######9    |  70%
# basemap-1.3.0        | 15.2 MB   | #######    |  70%
# basemap-1.3.0        | 15.2 MB   | #######    |  70%
# basemap-1.3.0        | 15.2 MB   | #######    |  71%
# basemap-1.3.0        | 15.2 MB   | #######1   |  71%
# basemap-1.3.0        | 15.2 MB   | #######1   |  71%
# basemap-1.3.0        | 15.2 MB   | #######1   |  72%
# basemap-1.3.0        | 15.2 MB   | #######1   |  72%
# basemap-1.3.0        | 15.2 MB   | #######2   |  72%
# basemap-1.3.0        | 15.2 MB   | #######2   |  72%
# basemap-1.3.0        | 15.2 MB   | #######2   |  73%
# basemap-1.3.0        | 15.2 MB   | #######3   |  73%
# basemap-1.3.0        | 15.2 MB   | #######3   |  73%
# basemap-1.3.0        | 15.2 MB   | #######3   |  74%
# basemap-1.3.0        | 15.2 MB   | #######3   |  74%
# basemap-1.3.0        | 15.2 MB   | #######4   |  74%
# basemap-1.3.0        | 15.2 MB   | #######4   |  75%
# basemap-1.3.0        | 15.2 MB   | #######4   |  75%
# basemap-1.3.0        | 15.2 MB   | #######5   |  75%
# basemap-1.3.0        | 15.2 MB   | #######5   |  76%
# basemap-1.3.0        | 15.2 MB   | #######5   |  76%
# basemap-1.3.0        | 15.2 MB   | #######6   |  76%
# basemap-1.3.0        | 15.2 MB   | #######6   |  77%
# basemap-1.3.0        | 15.2 MB   | #######6   |  77%
# basemap-1.3.0        | 15.2 MB   | #######7   |  77%
# basemap-1.3.0        | 15.2 MB   | #######7   |  77%
# basemap-1.3.0        | 15.2 MB   | #######7   |  78%
# basemap-1.3.0        | 15.2 MB   | #######8   |  78%
# basemap-1.3.0        | 15.2 MB   | #######8   |  79%
# basemap-1.3.0        | 15.2 MB   | #######8   |  79%
# basemap-1.3.0        | 15.2 MB   | #######9   |  79%
# basemap-1.3.0        | 15.2 MB   | #######9   |  79%
# basemap-1.3.0        | 15.2 MB   | #######9   |  80%
# basemap-1.3.0        | 15.2 MB   | ########   |  80%
# basemap-1.3.0        | 15.2 MB   | ########   |  80%
# basemap-1.3.0        | 15.2 MB   | ########   |  81%
# basemap-1.3.0        | 15.2 MB   | ########1  |  81%
# basemap-1.3.0        | 15.2 MB   | ########1  |  81%
# basemap-1.3.0        | 15.2 MB   | ########1  |  82%
# basemap-1.3.0        | 15.2 MB   | ########2  |  82%
# basemap-1.3.0        | 15.2 MB   | ########2  |  83%
# basemap-1.3.0        | 15.2 MB   | ########3  |  83%
# basemap-1.3.0        | 15.2 MB   | ########3  |  83%
# basemap-1.3.0        | 15.2 MB   | ########3  |  84%
# basemap-1.3.0        | 15.2 MB   | ########4  |  84%
# basemap-1.3.0        | 15.2 MB   | ########4  |  84%
# basemap-1.3.0        | 15.2 MB   | ########4  |  85%
# basemap-1.3.0        | 15.2 MB   | ########5  |  85%
# basemap-1.3.0        | 15.2 MB   | ########5  |  86%
# basemap-1.3.0        | 15.2 MB   | ########5  |  86%
# basemap-1.3.0        | 15.2 MB   | ########6  |  86%
# basemap-1.3.0        | 15.2 MB   | ########6  |  87%
# basemap-1.3.0        | 15.2 MB   | ########6  |  87%
# basemap-1.3.0        | 15.2 MB   | ########7  |  87%
# basemap-1.3.0        | 15.2 MB   | ########7  |  87%
# basemap-1.3.0        | 15.2 MB   | ########7  |  88%
# basemap-1.3.0        | 15.2 MB   | ########8  |  88%
# basemap-1.3.0        | 15.2 MB   | ########8  |  88%
# basemap-1.3.0        | 15.2 MB   | ########8  |  89%
# basemap-1.3.0        | 15.2 MB   | ########9  |  89%
# basemap-1.3.0        | 15.2 MB   | ########9  |  89%
# basemap-1.3.0        | 15.2 MB   | ########9  |  90%
# basemap-1.3.0        | 15.2 MB   | #########  |  90%
# basemap-1.3.0        | 15.2 MB   | #########  |  90%
# basemap-1.3.0        | 15.2 MB   | #########  |  91%
# basemap-1.3.0        | 15.2 MB   | #########1 |  91%
# basemap-1.3.0        | 15.2 MB   | #########1 |  91%
# basemap-1.3.0        | 15.2 MB   | #########1 |  92%
# basemap-1.3.0        | 15.2 MB   | #########1 |  92%
# basemap-1.3.0        | 15.2 MB   | #########2 |  92%
# basemap-1.3.0        | 15.2 MB   | #########2 |  92%
# basemap-1.3.0        | 15.2 MB   | #########2 |  93%
# basemap-1.3.0        | 15.2 MB   | #########2 |  93%
# basemap-1.3.0        | 15.2 MB   | #########3 |  93%
# basemap-1.3.0        | 15.2 MB   | #########3 |  94%
# basemap-1.3.0        | 15.2 MB   | #########3 |  94%
# basemap-1.3.0        | 15.2 MB   | #########4 |  94%
# basemap-1.3.0        | 15.2 MB   | #########4 |  95%
# basemap-1.3.0        | 15.2 MB   | #########5 |  95%
# basemap-1.3.0        | 15.2 MB   | #########5 |  95%
# basemap-1.3.0        | 15.2 MB   | #########5 |  96%
# basemap-1.3.0        | 15.2 MB   | #########5 |  96%
# basemap-1.3.0        | 15.2 MB   | #########6 |  96%
# basemap-1.3.0        | 15.2 MB   | #########6 |  97%
# basemap-1.3.0        | 15.2 MB   | #########6 |  97%
# basemap-1.3.0        | 15.2 MB   | #########7 |  97%
# basemap-1.3.0        | 15.2 MB   | #########7 |  98%
# basemap-1.3.0        | 15.2 MB   | #########7 |  98%
# basemap-1.3.0        | 15.2 MB   | #########8 |  98%
# basemap-1.3.0        | 15.2 MB   | #########8 |  99%
# basemap-1.3.0        | 15.2 MB   | #########9 |  99%
# basemap-1.3.0        | 15.2 MB   | #########9 | 100%
# basemap-1.3.0        | 15.2 MB   | #########9 | 100%
# basemap-1.3.0        | 15.2 MB   | ########## | 100%
#
# matplotlib-base-3.2. | 7.1 MB    |            |   0%
# matplotlib-base-3.2. | 7.1 MB    |            |   0%
# matplotlib-base-3.2. | 7.1 MB    |            |   0%
# matplotlib-base-3.2. | 7.1 MB    | 1          |   1%
# matplotlib-base-3.2. | 7.1 MB    | 1          |   2%
# matplotlib-base-3.2. | 7.1 MB    | 2          |   3%
# matplotlib-base-3.2. | 7.1 MB    | 3          |   4%
# matplotlib-base-3.2. | 7.1 MB    | 4          |   4%
# matplotlib-base-3.2. | 7.1 MB    | 5          |   5%
# matplotlib-base-3.2. | 7.1 MB    | 5          |   6%
# matplotlib-base-3.2. | 7.1 MB    | 6          |   6%
# matplotlib-base-3.2. | 7.1 MB    | 6          |   7%
# matplotlib-base-3.2. | 7.1 MB    | 7          |   8%
# matplotlib-base-3.2. | 7.1 MB    | 8          |   9%
# matplotlib-base-3.2. | 7.1 MB    | 9          |   9%
# matplotlib-base-3.2. | 7.1 MB    | 9          |  10%
# matplotlib-base-3.2. | 7.1 MB    | #          |  11%
# matplotlib-base-3.2. | 7.1 MB    | #1         |  11%
# matplotlib-base-3.2. | 7.1 MB    | #1         |  12%
# matplotlib-base-3.2. | 7.1 MB    | #2         |  13%
# matplotlib-base-3.2. | 7.1 MB    | #3         |  14%
# matplotlib-base-3.2. | 7.1 MB    | #4         |  14%
# matplotlib-base-3.2. | 7.1 MB    | #4         |  15%
# matplotlib-base-3.2. | 7.1 MB    | #5         |  16%
# matplotlib-base-3.2. | 7.1 MB    | #6         |  16%
# matplotlib-base-3.2. | 7.1 MB    | #7         |  17%
# matplotlib-base-3.2. | 7.1 MB    | #7         |  18%
# matplotlib-base-3.2. | 7.1 MB    | #8         |  19%
# matplotlib-base-3.2. | 7.1 MB    | #9         |  19%
# matplotlib-base-3.2. | 7.1 MB    | ##         |  20%
# matplotlib-base-3.2. | 7.1 MB    | ##         |  21%
# matplotlib-base-3.2. | 7.1 MB    | ##1        |  21%
# matplotlib-base-3.2. | 7.1 MB    | ##2        |  22%
# matplotlib-base-3.2. | 7.1 MB    | ##2        |  23%
# matplotlib-base-3.2. | 7.1 MB    | ##3        |  23%
# matplotlib-base-3.2. | 7.1 MB    | ##3        |  24%
# matplotlib-base-3.2. | 7.1 MB    | ##4        |  24%
# matplotlib-base-3.2. | 7.1 MB    | ##4        |  25%
# matplotlib-base-3.2. | 7.1 MB    | ##5        |  25%
# matplotlib-base-3.2. | 7.1 MB    | ##5        |  26%
# matplotlib-base-3.2. | 7.1 MB    | ##6        |  27%
# matplotlib-base-3.2. | 7.1 MB    | ##7        |  27%
# matplotlib-base-3.2. | 7.1 MB    | ##8        |  28%
# matplotlib-base-3.2. | 7.1 MB    | ##8        |  29%
# matplotlib-base-3.2. | 7.1 MB    | ##9        |  30%
# matplotlib-base-3.2. | 7.1 MB    | ###        |  30%
# matplotlib-base-3.2. | 7.1 MB    | ###1       |  31%
# matplotlib-base-3.2. | 7.1 MB    | ###1       |  32%
# matplotlib-base-3.2. | 7.1 MB    | ###2       |  33%
# matplotlib-base-3.2. | 7.1 MB    | ###3       |  33%
# matplotlib-base-3.2. | 7.1 MB    | ###3       |  34%
# matplotlib-base-3.2. | 7.1 MB    | ###4       |  35%
# matplotlib-base-3.2. | 7.1 MB    | ###5       |  35%
# matplotlib-base-3.2. | 7.1 MB    | ###6       |  36%
# matplotlib-base-3.2. | 7.1 MB    | ###6       |  37%
# matplotlib-base-3.2. | 7.1 MB    | ###7       |  37%
# matplotlib-base-3.2. | 7.1 MB    | ###7       |  38%
# matplotlib-base-3.2. | 7.1 MB    | ###8       |  39%
# matplotlib-base-3.2. | 7.1 MB    | ###8       |  39%
# matplotlib-base-3.2. | 7.1 MB    | ###9       |  40%
# matplotlib-base-3.2. | 7.1 MB    | ####       |  40%
# matplotlib-base-3.2. | 7.1 MB    | ####       |  40%
# matplotlib-base-3.2. | 7.1 MB    | ####       |  41%
# matplotlib-base-3.2. | 7.1 MB    | ####1      |  41%
# matplotlib-base-3.2. | 7.1 MB    | ####2      |  42%
# matplotlib-base-3.2. | 7.1 MB    | ####2      |  43%
# matplotlib-base-3.2. | 7.1 MB    | ####3      |  43%
# matplotlib-base-3.2. | 7.1 MB    | ####3      |  44%
# matplotlib-base-3.2. | 7.1 MB    | ####4      |  44%
# matplotlib-base-3.2. | 7.1 MB    | ####4      |  45%
# matplotlib-base-3.2. | 7.1 MB    | ####5      |  45%
# matplotlib-base-3.2. | 7.1 MB    | ####5      |  46%
# matplotlib-base-3.2. | 7.1 MB    | ####6      |  46%
# matplotlib-base-3.2. | 7.1 MB    | ####6      |  47%
# matplotlib-base-3.2. | 7.1 MB    | ####7      |  47%
# matplotlib-base-3.2. | 7.1 MB    | ####7      |  48%
# matplotlib-base-3.2. | 7.1 MB    | ####8      |  48%
# matplotlib-base-3.2. | 7.1 MB    | ####8      |  49%
# matplotlib-base-3.2. | 7.1 MB    | ####9      |  50%
# matplotlib-base-3.2. | 7.1 MB    | #####      |  51%
# matplotlib-base-3.2. | 7.1 MB    | #####1     |  52%
# matplotlib-base-3.2. | 7.1 MB    | #####2     |  52%
# matplotlib-base-3.2. | 7.1 MB    | #####3     |  53%
# matplotlib-base-3.2. | 7.1 MB    | #####4     |  54%
# matplotlib-base-3.2. | 7.1 MB    | #####4     |  54%
# matplotlib-base-3.2. | 7.1 MB    | #####5     |  56%
# matplotlib-base-3.2. | 7.1 MB    | #####6     |  56%
# matplotlib-base-3.2. | 7.1 MB    | #####7     |  57%
# matplotlib-base-3.2. | 7.1 MB    | #####7     |  58%
# matplotlib-base-3.2. | 7.1 MB    | #####8     |  58%
# matplotlib-base-3.2. | 7.1 MB    | #####9     |  60%
# matplotlib-base-3.2. | 7.1 MB    | ######     |  60%
# matplotlib-base-3.2. | 7.1 MB    | ######1    |  61%
# matplotlib-base-3.2. | 7.1 MB    | ######1    |  62%
# matplotlib-base-3.2. | 7.1 MB    | ######4    |  64%
# matplotlib-base-3.2. | 7.1 MB    | ######5    |  65%
# matplotlib-base-3.2. | 7.1 MB    | ######6    |  66%
# matplotlib-base-3.2. | 7.1 MB    | ######7    |  67%
# matplotlib-base-3.2. | 7.1 MB    | ######8    |  68%
# matplotlib-base-3.2. | 7.1 MB    | ######9    |  69%
# matplotlib-base-3.2. | 7.1 MB    | #######    |  70%
# matplotlib-base-3.2. | 7.1 MB    | #######1   |  72%
# matplotlib-base-3.2. | 7.1 MB    | #######3   |  73%
# matplotlib-base-3.2. | 7.1 MB    | #######4   |  74%
# matplotlib-base-3.2. | 7.1 MB    | #######5   |  76%
# matplotlib-base-3.2. | 7.1 MB    | #######6   |  77%
# matplotlib-base-3.2. | 7.1 MB    | #######8   |  78%
# matplotlib-base-3.2. | 7.1 MB    | #######9   |  79%
# matplotlib-base-3.2. | 7.1 MB    | ########   |  80%
# matplotlib-base-3.2. | 7.1 MB    | ########2  |  82%
# matplotlib-base-3.2. | 7.1 MB    | ########3  |  83%
# matplotlib-base-3.2. | 7.1 MB    | ########4  |  84%
# matplotlib-base-3.2. | 7.1 MB    | ########5  |  86%
# matplotlib-base-3.2. | 7.1 MB    | ########6  |  87%
# matplotlib-base-3.2. | 7.1 MB    | ########7  |  88%
# matplotlib-base-3.2. | 7.1 MB    | ########8  |  89%
# matplotlib-base-3.2. | 7.1 MB    | ########9  |  90%
# matplotlib-base-3.2. | 7.1 MB    | #########1 |  91%
# matplotlib-base-3.2. | 7.1 MB    | #########2 |  92%
# matplotlib-base-3.2. | 7.1 MB    | #########3 |  94%
# matplotlib-base-3.2. | 7.1 MB    | #########5 |  95%
# matplotlib-base-3.2. | 7.1 MB    | #########6 |  97%
# matplotlib-base-3.2. | 7.1 MB    | #########8 |  98%
# matplotlib-base-3.2. | 7.1 MB    | #########9 | 100%
# proj-7.0.0           | 2.3 MB    |            |   0%
# proj-7.0.0           | 2.3 MB    |            |   1%
# proj-7.0.0           | 2.3 MB    | 4          |   5%
# proj-7.0.0           | 2.3 MB    | 8          |   8%
# proj-7.0.0           | 2.3 MB    | #3         |  13%
# proj-7.0.0           | 2.3 MB    | #7         |  18%
# proj-7.0.0           | 2.3 MB    | ##3        |  23%
# proj-7.0.0           | 2.3 MB    | ##8        |  29%
# proj-7.0.0           | 2.3 MB    | ###4       |  35%
# proj-7.0.0           | 2.3 MB    | ###9       |  40%
# proj-7.0.0           | 2.3 MB    | ####4      |  44%
# proj-7.0.0           | 2.3 MB    | #####1     |  51%
# proj-7.0.0           | 2.3 MB    | #####6     |  57%
# proj-7.0.0           | 2.3 MB    | ######2    |  62%
# proj-7.0.0           | 2.3 MB    | ######7    |  68%
# proj-7.0.0           | 2.3 MB    | #######3   |  73%
# proj-7.0.0           | 2.3 MB    | #######8   |  79%
# proj-7.0.0           | 2.3 MB    | ########4  |  84%
# proj-7.0.0           | 2.3 MB    | ########9  |  90%
# proj-7.0.0           | 2.3 MB    | #########5 |  95%
# proj-7.0.0           | 2.3 MB    | ########## | 100%
#
# intel-openmp-2020.0  | 1.5 MB    |            |   0%
# intel-openmp-2020.0  | 1.5 MB    | 1          |   1%
# intel-openmp-2020.0  | 1.5 MB    | 9          |   9%
# intel-openmp-2020.0  | 1.5 MB    | #7         |  18%
# intel-openmp-2020.0  | 1.5 MB    | ##5        |  26%
# intel-openmp-2020.0  | 1.5 MB    | ###5       |  35%
# intel-openmp-2020.0  | 1.5 MB    | ####1      |  41%
# intel-openmp-2020.0  | 1.5 MB    | #####4     |  55%
# intel-openmp-2020.0  | 1.5 MB    | ########4  |  85%
# intel-openmp-2020.0  | 1.5 MB    | #########9 |  99%
# intel-openmp-2020.0  | 1.5 MB    | ########## | 100%
#
# liblapack-3.8.0      | 3.5 MB    |            |   0%
# liblapack-3.8.0      | 3.5 MB    |            |   0%
# liblapack-3.8.0      | 3.5 MB    | 4          |   4%
# liblapack-3.8.0      | 3.5 MB    | 8          |   8%
# liblapack-3.8.0      | 3.5 MB    | #1         |  12%
# liblapack-3.8.0      | 3.5 MB    | #5         |  16%
# liblapack-3.8.0      | 3.5 MB    | #9         |  20%
# liblapack-3.8.0      | 3.5 MB    | ##2        |  23%
# liblapack-3.8.0      | 3.5 MB    | ##8        |  28%
# liblapack-3.8.0      | 3.5 MB    | ###1       |  32%
# liblapack-3.8.0      | 3.5 MB    | ###5       |  36%
# liblapack-3.8.0      | 3.5 MB    | ###8       |  39%
# liblapack-3.8.0      | 3.5 MB    | ####2      |  42%
# liblapack-3.8.0      | 3.5 MB    | ####5      |  46%
# liblapack-3.8.0      | 3.5 MB    | ####9      |  50%
# liblapack-3.8.0      | 3.5 MB    | #####3     |  53%
# liblapack-3.8.0      | 3.5 MB    | #####8     |  59%
# liblapack-3.8.0      | 3.5 MB    | ######8    |  69%
# liblapack-3.8.0      | 3.5 MB    | #######4   |  74%
# liblapack-3.8.0      | 3.5 MB    | #######8   |  78%
# liblapack-3.8.0      | 3.5 MB    | ########2  |  83%
# liblapack-3.8.0      | 3.5 MB    | #########1 |  91%
# liblapack-3.8.0      | 3.5 MB    | #########6 |  96%
# liblapack-3.8.0      | 3.5 MB    | ########## | 100%
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename C:\Users\CHIRAG\Anaconda3\Lib\site-packages\matplotlib\mpl-data\fonts\ttf\DejaVuSans-Bold.ttf.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename C:\Users\CHIRAG\Anaconda3\Lib\site-packages\matplotlib\mpl-data\fonts\ttf\DejaVuSans.ttf.  Please remove this file manually (you may need to reboot to free file handles)

# %%
import numpy as np 
from sklearn.cluster import DBSCAN 
from sklearn.datasets import make_blobs 
from sklearn.preprocessing import StandardScaler 
import matplotlib.pyplot as plt 
# %matplotlib inline

# %% [markdown]
# ### Data generation
# The function below will generate the data points and requires these inputs:
# <ul>
#     <li> <b>centroidLocation</b>: Coordinates of the centroids that will generate the random data. </li>
#     <ul> <li> Example: input: [[4,3], [2,-1], [-1,4]] </li> </ul>
#     <li> <b>numSamples</b>: The number of data points we want generated, split over the number of centroids (# of centroids defined in centroidLocation) </li>
#     <ul> <li> Example: 1500 </li> </ul>
#     <li> <b>clusterDeviation</b>: The standard deviation between the clusters. The larger the number, the further the spacing. </li>
#     <ul> <li> Example: 0.5 </li> </ul>
# </ul>

# %%
def createDataPoints(centroidLocation, numSamples, clusterDeviation):
    # Create random data and store in feature matrix X and response vector y.
    X, y = make_blobs(n_samples=numSamples, centers=centroidLocation, 
                                cluster_std=clusterDeviation)
    
    # Standardize features by removing the mean and scaling to unit variance
    X = StandardScaler().fit_transform(X)
    return X, y

# %% [markdown]
# Use <b>createDataPoints</b> with the <b>3 inputs</b> and store the output into variables <b>X</b> and <b>y</b>.

# %%
X, y = createDataPoints([[4,3], [2,-1], [-1,4]] , 1500, 0.5)

# %% [markdown]
# ### Modeling
# DBSCAN stands for Density-Based Spatial Clustering of Applications with Noise. This technique is one of the most common clustering algorithms  which works based on density of object.
# The whole idea is that if a particular point belongs to a cluster, it should be near to lots of other points in that cluster.
#
# It works based on two parameters: Epsilon and Minimum Points
# __Epsilon__ determine a specified radius that if includes enough number of points within, we call it dense area
# __minimumSamples__ determine the minimum number of data points we want in a neighborhood to define a cluster.

# %%
epsilon = 0.3
minimumSamples = 7
db = DBSCAN(eps=epsilon, min_samples=minimumSamples).fit(X)
labels = db.labels_
labels
# Out:
# array([0, 1, 0, ..., 0, 0, 1], dtype=int64)

# %% [markdown]
# ### Distinguish outliers
# Lets Replace all elements with 'True' in core_samples_mask that are in the cluster, 'False' if the points are outliers.

# %%
# Firts, create an array of booleans using the labels from db.
core_samples_mask = np.zeros_like(db.labels_, dtype=bool)
core_samples_mask[db.core_sample_indices_] = True
core_samples_mask
# Out:
# array([ True,  True,  True, ...,  True,  True,  True])

# %%
# Number of clusters in labels, ignoring noise if present.
n_clusters_ = len(set(labels)) - (1 if -1 in labels else 0)
n_clusters_
# Out:
# 3

# %%
# Remove repetition in labels by turning it into a set.
unique_labels = set(labels)
unique_labels
# Out:
# {-1, 0, 1, 2}

# %% [markdown]
# ### Data visualization

# %%
# Create colors for the clusters.
colors = plt.cm.Spectral(np.linspace(0, 1, len(unique_labels)))

# %%
# Plot the points with colors
for k, col in zip(unique_labels, colors):
    if k == -1:
        # Black used for noise.
        col = 'k'

    class_member_mask = (labels == k)

    # Plot the datapoints that are clustered
    xy = X[class_member_mask & core_samples_mask]
    plt.scatter(xy[:, 0], xy[:, 1],s=50, c=[col], marker=u'o', alpha=0.5)

    # Plot the outliers
    xy = X[class_member_mask & ~core_samples_mask]
    plt.scatter(xy[:, 0], xy[:, 1],s=50, c=[col], marker=u'o', alpha=0.5)

# %% [markdown]
# ## Practice
# To better underestand differences between partitional and density-based clusteitng, try to cluster the above dataset into 3 clusters using k-Means.
# Notice: do not generate data again, use the same dataset as above.

# %%
# write your code here
from sklearn.cluster import KMeans
kkr = KMeans(n_clusters=3, n_init=12)
kkr.fit(X)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#        n_clusters=3, n_init=12, n_jobs=None, precompute_distances='auto',
#        random_state=None, tol=0.0001, verbose=0)

# %%
kkr.cluster_centers_
# Out:
# array([[-1.25677763,  0.90371307],
#        [ 0.14600833, -1.35168854],
#        [ 1.1107693 ,  0.44797547]])

# %%
for k, col in zip(unique_labels, colors):
    if k == -1:
        # Black used for noise.
        col = 'k'

    class_member_mask = (labels == k)

    # Plot the datapoints that are clustered
    xy = X[class_member_mask & core_samples_mask]
    plt.scatter(xy[:, 0], xy[:, 1],s=50, c=[col], marker=u'o', alpha=0.5)

    # Plot the outliers
    xy = X[class_member_mask & ~core_samples_mask]
    plt.scatter(xy[:, 0], xy[:, 1],s=50, c=[col], marker=u'o', alpha=0.5)

# %% [markdown]
# Double-click __here__ for the solution.
#
# <!-- Your answer is below:
#
#
# from sklearn.cluster import KMeans
# k = 3
# k_means3 = KMeans(init = "k-means++", n_clusters = k, n_init = 12)
# k_means3.fit(X)
# fig = plt.figure(figsize=(6, 4))
# ax = fig.add_subplot(1, 1, 1)
# for k, col in zip(range(k), colors):
#     my_members = (k_means3.labels_ == k)
#     plt.scatter(X[my_members, 0], X[my_members, 1],  c=col, marker=u'o', alpha=0.5)
# plt.show()
#
#
# -->

# %% [markdown]
# <h1 align=center> Weather Station Clustering using DBSCAN & scikit-learn </h1>
# <hr>
#
# DBSCAN is specially very good for tasks like class identification on a spatial context. The wonderful attribute of DBSCAN algorithm is that it can find out any arbitrary shape cluster without getting affected by noise. For example, this following example cluster the location of weather stations in Canada.
# <Click 1>
# DBSCAN can be used here, for instance, to find the group of stations which show the same weather condition. As you can see, it not only finds different arbitrary shaped clusters, can find the denser part of data-centered samples by ignoring less-dense areas or noises.
#
# let's start playing with the data. We will be working according to the following workflow: </font>
# 1. Loading data
# - Overview data
# - Data cleaning
# - Data selection
# - Clusteing

# %% [markdown]
# ### About the dataset
#
#
# <h4 align = "center">
# Environment Canada
# Monthly Values for July - 2015
# </h4>
# <html>
# <head>
# <style>
# table {
#     font-family: arial, sans-serif;
#     border-collapse: collapse;
#     width: 100%;
# }
#
# td, th {
#     border: 1px solid #dddddd;
#     text-align: left;
#     padding: 8px;
# }
#
# tr:nth-child(even) {
#     background-color: #dddddd;
# }
# </style>
# </head>
# <body>
#
# <table>
#   <tr>
#     <th>Name in the table</th>
#     <th>Meaning</th>
#   </tr>
#   <tr>
#     <td><font color = "green"><strong>Stn_Name</font></td>
#     <td><font color = "green"><strong>Station Name</font</td>
#   </tr>
#   <tr>
#     <td><font color = "green"><strong>Lat</font></td>
#     <td><font color = "green"><strong>Latitude (North+, degrees)</font></td>
#   </tr>
#   <tr>
#     <td><font color = "green"><strong>Long</font></td>
#     <td><font color = "green"><strong>Longitude (West - , degrees)</font></td>
#   </tr>
#   <tr>
#     <td>Prov</td>
#     <td>Province</td>
#   </tr>
#   <tr>
#     <td>Tm</td>
#     <td>Mean Temperature (°C)</td>
#   </tr>
#   <tr>
#     <td>DwTm</td>
#     <td>Days without Valid Mean Temperature</td>
#   </tr>
#   <tr>
#     <td>D</td>
#     <td>Mean Temperature difference from Normal (1981-2010) (°C)</td>
#   </tr>
#   <tr>
#     <td><font color = "black">Tx</font></td>
#     <td><font color = "black">Highest Monthly Maximum Temperature (°C)</font></td>
#   </tr>
#   <tr>
#     <td>DwTx</td>
#     <td>Days without Valid Maximum Temperature</td>
#   </tr>
#   <tr>
#     <td><font color = "black">Tn</font></td>
#     <td><font color = "black">Lowest Monthly Minimum Temperature (°C)</font></td>
#   </tr>
#   <tr>
#     <td>DwTn</td>
#     <td>Days without Valid Minimum Temperature</td>
#   </tr>
#   <tr>
#     <td>S</td>
#     <td>Snowfall (cm)</td>
#   </tr>
#   <tr>
#     <td>DwS</td>
#     <td>Days without Valid Snowfall</td>
#   </tr>
#   <tr>
#     <td>S%N</td>
#     <td>Percent of Normal (1981-2010) Snowfall</td>
#   </tr>
#   <tr>
#     <td><font color = "green"><strong>P</font></td>
#     <td><font color = "green"><strong>Total Precipitation (mm)</font></td>
#   </tr>
#   <tr>
#     <td>DwP</td>
#     <td>Days without Valid Precipitation</td>
#   </tr>
#   <tr>
#     <td>P%N</td>
#     <td>Percent of Normal (1981-2010) Precipitation</td>
#   </tr>
#   <tr>
#     <td>S_G</td>
#     <td>Snow on the ground at the end of the month (cm)</td>
#   </tr>
#   <tr>
#     <td>Pd</td>
#     <td>Number of days with Precipitation 1.0 mm or more</td>
#   </tr>
#   <tr>
#     <td>BS</td>
#     <td>Bright Sunshine (hours)</td>
#   </tr>
#   <tr>
#     <td>DwBS</td>
#     <td>Days without Valid Bright Sunshine</td>
#   </tr>
#   <tr>
#     <td>BS%</td>
#     <td>Percent of Normal (1981-2010) Bright Sunshine</td>
#   </tr>
#   <tr>
#     <td>HDD</td>
#     <td>Degree Days below 18 °C</td>
#   </tr>
#   <tr>
#     <td>CDD</td>
#     <td>Degree Days above 18 °C</td>
#   </tr>
#   <tr>
#     <td>Stn_No</td>
#     <td>Climate station identifier (first 3 digits indicate   drainage basin, last 4 characters are for sorting alphabetically).</td>
#   </tr>
#   <tr>
#     <td>NA</td>
#     <td>Not Available</td>
#   </tr>
#
#
# </table>
#
# </body>
# </html>

# %% [markdown]
# ### 1-Download data
# To download the data, we will use **`!wget`**. To download the data, we will use `!wget` to download it from IBM Object Storage.
# __Did you know?__ When it comes to Machine Learning, you will likely be working with large datasets. As a business, where can you host your data? IBM is offering a unique opportunity for businesses, with 10 Tb of IBM Cloud Object Storage: [Sign up now for free](http://cocl.us/ML0101EN-IBM-Offer-CC)

# %%
# !wget -O weather-stations20140101-20141231.csv https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/ML0101ENv3/labs/weather-stations20140101-20141231.csv
# Out:
# 'wget' is not recognized as an internal or external command,
# operable program or batch file.

# %% [markdown]
# ### 2- Load the dataset
# We will import the .csv then we creates the columns for year, month and day.

# %%
import csv
import pandas as pd
import numpy as np

filename='https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/ML0101ENv3/labs/weather-stations20140101-20141231.csv'

#Read csv
pdf = pd.read_csv(filename)
pdf.head(5)
# Out:
#                  Stn_Name     Lat     Long Prov   Tm  DwTm    D    Tx  DwTx  \
# 0               CHEMAINUS  48.935 -123.742   BC  8.2   0.0  NaN  13.5   0.0
# 1  COWICHAN LAKE FORESTRY  48.824 -124.133   BC  7.0   0.0  3.0  15.0   0.0
# 2           LAKE COWICHAN  48.829 -124.052   BC  6.8  13.0  2.8  16.0   9.0
# 3        DISCOVERY ISLAND  48.425 -123.226   BC  NaN   NaN  NaN  12.5   0.0
# 4     DUNCAN KELVIN CREEK  48.735 -123.728   BC  7.7   2.0  3.4  14.5   2.0
#
#     Tn  ...  DwP    P%N  S_G    Pd  BS  DwBS  BS%    HDD  CDD   Stn_No
# 0  1.0  ...  0.0    NaN  0.0  12.0 NaN   NaN  NaN  273.3  0.0  1011500
# 1 -3.0  ...  0.0  104.0  0.0  12.0 NaN   NaN  NaN  307.0  0.0  1012040
# 2 -2.5  ...  9.0    NaN  NaN  11.0 NaN   NaN  NaN  168.1  0.0  1012055
# 3  NaN  ...  NaN    NaN  NaN   NaN NaN   NaN  NaN    NaN  NaN  1012475
# 4 -1.0  ...  2.0    NaN  NaN  11.0 NaN   NaN  NaN  267.7  0.0  1012573
#
# [5 rows x 25 columns]

# %% [markdown]
# ### 3-Cleaning
# Lets remove rows that dont have any value in the __Tm__ field.

# %%
pdf = pdf[pd.notnull(pdf["Tm"])]
pdf = pdf.reset_index(drop=True)
pdf.head(5)
# Out:
#                  Stn_Name     Lat     Long Prov   Tm  DwTm    D    Tx  DwTx  \
# 0               CHEMAINUS  48.935 -123.742   BC  8.2   0.0  NaN  13.5   0.0
# 1  COWICHAN LAKE FORESTRY  48.824 -124.133   BC  7.0   0.0  3.0  15.0   0.0
# 2           LAKE COWICHAN  48.829 -124.052   BC  6.8  13.0  2.8  16.0   9.0
# 3     DUNCAN KELVIN CREEK  48.735 -123.728   BC  7.7   2.0  3.4  14.5   2.0
# 4       ESQUIMALT HARBOUR  48.432 -123.439   BC  8.8   0.0  NaN  13.1   0.0
#
#     Tn  ...  DwP    P%N  S_G    Pd  BS  DwBS  BS%    HDD  CDD   Stn_No
# 0  1.0  ...  0.0    NaN  0.0  12.0 NaN   NaN  NaN  273.3  0.0  1011500
# 1 -3.0  ...  0.0  104.0  0.0  12.0 NaN   NaN  NaN  307.0  0.0  1012040
# 2 -2.5  ...  9.0    NaN  NaN  11.0 NaN   NaN  NaN  168.1  0.0  1012055
# 3 -1.0  ...  2.0    NaN  NaN  11.0 NaN   NaN  NaN  267.7  0.0  1012573
# 4  1.9  ...  8.0    NaN  NaN  12.0 NaN   NaN  NaN  258.6  0.0  1012710
#
# [5 rows x 25 columns]

# %% [markdown]
# ### 4-Visualization
# Visualization of stations on map using basemap package. The matplotlib basemap toolkit is a library for plotting 2D data on maps in Python. Basemap does not do any plotting on it’s own, but provides the facilities to transform coordinates to a map projections.
#
# Please notice that the size of each data points represents the average of maximum temperature for each station in a year.

# %%
from mpl_toolkits.basemap import Basemap
import matplotlib.pyplot as plt
from pylab import rcParams
# %matplotlib inline
rcParams['figure.figsize'] = (14,10)

llon=-140
ulon=-50
llat=40
ulat=65

pdf = pdf[(pdf['Long'] > llon) & (pdf['Long'] < ulon) & (pdf['Lat'] > llat) &(pdf['Lat'] < ulat)]

my_map = Basemap(projection='merc',
            resolution = 'l', area_thresh = 1000.0,
            llcrnrlon=llon, llcrnrlat=llat, #min longitude (llcrnrlon) and latitude (llcrnrlat)
            urcrnrlon=ulon, urcrnrlat=ulat) #max longitude (urcrnrlon) and latitude (urcrnrlat)

my_map.drawcoastlines()
my_map.drawcountries()
# my_map.drawmapboundary()
my_map.fillcontinents(color = 'white', alpha = 0.3)
my_map.shadedrelief()

# To collect data based on stations        

xs,ys = my_map(np.asarray(pdf.Long), np.asarray(pdf.Lat))
pdf['xm']= xs.tolist()
pdf['ym'] =ys.tolist()

#Visualization1
for index,row in pdf.iterrows():
#   x,y = my_map(row.Long, row.Lat)
   my_map.plot(row.xm, row.ym,markerfacecolor =([1,0,0]),  marker='o', markersize= 5, alpha = 0.75)
#plt.text(x,y,stn)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-17-6b98a7110c83> in <module>
# ----> 1 from mpl_toolkits.basemap import Basemap
#       2 import matplotlib.pyplot as plt
#       3 from pylab import rcParams
#       4 get_ipython().run_line_magic('matplotlib', 'inline')
#       5 rcParams['figure.figsize'] = (14,10)
#
# ~\Anaconda3\lib\site-packages\mpl_toolkits\basemap\__init__.py in <module>
#     150
#     151 # create dictionary that maps epsg codes to Basemap kwargs.
# --> 152 pyproj_datadir = os.environ['PROJ_LIB']
#     153 epsgf = open(os.path.join(basemap_datadir,'epsg'))
#     154 epsg_dict={}
#
# ~\Anaconda3\lib\os.py in __getitem__(self, key)
#     676         except KeyError:
#     677             # raise KeyError with the original key value
# --> 678             raise KeyError(key) from None
#     679         return self.decodevalue(value)
#     680
#
# KeyError: 'PROJ_LIB'

# %% [markdown]
# ### 5- Clustering of stations based on their location i.e. Lat & Lon
#
# __DBSCAN__ form sklearn library can runs DBSCAN clustering from vector array or distance matrix. In our case, we pass it the Numpy array Clus_dataSet to find core samples of high density and expands clusters from them.

# %%
from sklearn.cluster import DBSCAN
import sklearn.utils
from sklearn.preprocessing import StandardScaler
sklearn.utils.check_random_state(1000)
Clus_dataSet = pdf[['xm','ym']]
Clus_dataSet = np.nan_to_num(Clus_dataSet)
Clus_dataSet = StandardScaler().fit_transform(Clus_dataSet)

# Compute DBSCAN
db = DBSCAN(eps=0.15, min_samples=10).fit(Clus_dataSet)
core_samples_mask = np.zeros_like(db.labels_, dtype=bool)
core_samples_mask[db.core_sample_indices_] = True
labels = db.labels_
pdf["Clus_Db"]=labels

realClusterNum=len(set(labels)) - (1 if -1 in labels else 0)
clusterNum = len(set(labels)) 


# A sample of clusters
pdf[["Stn_Name","Tx","Tm","Clus_Db"]].head(5)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-18-6300e51d4d85> in <module>
#       3 from sklearn.preprocessing import StandardScaler
#       4 sklearn.utils.check_random_state(1000)
# ----> 5 Clus_dataSet = pdf[['xm','ym']]
#       6 Clus_dataSet = np.nan_to_num(Clus_dataSet)
#       7 Clus_dataSet = StandardScaler().fit_transform(Clus_dataSet)
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2979             if is_iterator(key):
#    2980                 key = list(key)
# -> 2981             indexer = self.loc._convert_to_indexer(key, axis=1, raise_missing=True)
#    2982
#    2983         # take() does not accept boolean indexers
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in _convert_to_indexer(self, obj, axis, is_setter, raise_missing)
#    1269                 # When setting, missing keys are not allowed, even with .loc:
#    1270                 kwargs = {"raise_missing": True if is_setter else raise_missing}
# -> 1271                 return self._get_listlike_indexer(obj, axis, **kwargs)[1]
#    1272         else:
#    1273             try:
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1076
#    1077         self._validate_read_indexer(
# -> 1078             keyarr, indexer, o._get_axis_number(axis), raise_missing=raise_missing
#    1079         )
#    1080         return keyarr, indexer
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in _validate_read_indexer(self, key, indexer, axis, raise_missing)
#    1161                 raise KeyError(
#    1162                     "None of [{key}] are in the [{axis}]".format(
# -> 1163                         key=key, axis=self.obj._get_axis_name(axis)
#    1164                     )
#    1165                 )
#
# KeyError: "None of [Index(['xm', 'ym'], dtype='object')] are in the [columns]"

# %% [markdown]
# As you can see for outliers, the cluster label is -1

# %%
set(labels)
# Out:
# {-1, 0, 1, 2}

# %% [markdown]
# ### 6- Visualization of clusters based on location
# Now, we can visualize the clusters using basemap:

# %%
from mpl_toolkits.basemap import Basemap
import matplotlib.pyplot as plt
from pylab import rcParams
# %matplotlib inline
rcParams['figure.figsize'] = (14,10)

my_map = Basemap(projection='merc',
            resolution = 'l', area_thresh = 1000.0,
            llcrnrlon=llon, llcrnrlat=llat, #min longitude (llcrnrlon) and latitude (llcrnrlat)
            urcrnrlon=ulon, urcrnrlat=ulat) #max longitude (urcrnrlon) and latitude (urcrnrlat)

my_map.drawcoastlines()
my_map.drawcountries()
#my_map.drawmapboundary()
my_map.fillcontinents(color = 'white', alpha = 0.3)
my_map.shadedrelief()

# To create a color map
colors = plt.get_cmap('jet')(np.linspace(0.0, 1.0, clusterNum))



#Visualization1
for clust_number in set(labels):
    c=(([0.4,0.4,0.4]) if clust_number == -1 else colors[np.int(clust_number)])
    clust_set = pdf[pdf.Clus_Db == clust_number]                    
    my_map.scatter(clust_set.xm, clust_set.ym, color =c,  marker='o', s= 20, alpha = 0.85)
    if clust_number != -1:
        cenx=np.mean(clust_set.xm) 
        ceny=np.mean(clust_set.ym) 
        plt.text(cenx,ceny,str(clust_number), fontsize=25, color='red',)
        print ("Cluster "+str(clust_number)+', Avg Temp: '+ str(np.mean(clust_set.Tm)))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-20-814b2feba22e> in <module>
# ----> 1 from mpl_toolkits.basemap import Basemap
#       2 import matplotlib.pyplot as plt
#       3 from pylab import rcParams
#       4 get_ipython().run_line_magic('matplotlib', 'inline')
#       5 rcParams['figure.figsize'] = (14,10)
#
# ~\Anaconda3\lib\site-packages\mpl_toolkits\basemap\__init__.py in <module>
#     150
#     151 # create dictionary that maps epsg codes to Basemap kwargs.
# --> 152 pyproj_datadir = os.environ['PROJ_LIB']
#     153 epsgf = open(os.path.join(basemap_datadir,'epsg'))
#     154 epsg_dict={}
#
# ~\Anaconda3\lib\os.py in __getitem__(self, key)
#     676         except KeyError:
#     677             # raise KeyError with the original key value
# --> 678             raise KeyError(key) from None
#     679         return self.decodevalue(value)
#     680
#
# KeyError: 'PROJ_LIB'

# %% [markdown]
# ### 7- Clustering of stations based on their location, mean, max, and min Temperature
# In this section we re-run DBSCAN, but this time on a 5-dimensional dataset:

# %%
from sklearn.cluster import DBSCAN
import sklearn.utils
from sklearn.preprocessing import StandardScaler
sklearn.utils.check_random_state(1000)
Clus_dataSet = pdf[['xm','ym','Tx','Tm','Tn']]
Clus_dataSet = np.nan_to_num(Clus_dataSet)
Clus_dataSet = StandardScaler().fit_transform(Clus_dataSet)

# Compute DBSCAN
db = DBSCAN(eps=0.3, min_samples=10).fit(Clus_dataSet)
core_samples_mask = np.zeros_like(db.labels_, dtype=bool)
core_samples_mask[db.core_sample_indices_] = True
labels = db.labels_
pdf["Clus_Db"]=labels

realClusterNum=len(set(labels)) - (1 if -1 in labels else 0)
clusterNum = len(set(labels)) 


# A sample of clusters
pdf[["Stn_Name","Tx","Tm","Clus_Db"]].head(5)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-21-544e7ecd4e3f> in <module>
#       3 from sklearn.preprocessing import StandardScaler
#       4 sklearn.utils.check_random_state(1000)
# ----> 5 Clus_dataSet = pdf[['xm','ym','Tx','Tm','Tn']]
#       6 Clus_dataSet = np.nan_to_num(Clus_dataSet)
#       7 Clus_dataSet = StandardScaler().fit_transform(Clus_dataSet)
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2979             if is_iterator(key):
#    2980                 key = list(key)
# -> 2981             indexer = self.loc._convert_to_indexer(key, axis=1, raise_missing=True)
#    2982
#    2983         # take() does not accept boolean indexers
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in _convert_to_indexer(self, obj, axis, is_setter, raise_missing)
#    1269                 # When setting, missing keys are not allowed, even with .loc:
#    1270                 kwargs = {"raise_missing": True if is_setter else raise_missing}
# -> 1271                 return self._get_listlike_indexer(obj, axis, **kwargs)[1]
#    1272         else:
#    1273             try:
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1076
#    1077         self._validate_read_indexer(
# -> 1078             keyarr, indexer, o._get_axis_number(axis), raise_missing=raise_missing
#    1079         )
#    1080         return keyarr, indexer
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in _validate_read_indexer(self, key, indexer, axis, raise_missing)
#    1169             if not (self.name == "loc" and not raise_missing):
#    1170                 not_found = list(set(key) - set(ax))
# -> 1171                 raise KeyError("{} not in index".format(not_found))
#    1172
#    1173             # we skip the warning on Categorical/Interval
#
# KeyError: "['xm', 'ym'] not in index"

# %% [markdown]
# ### 8- Visualization of clusters based on location and Temperture

# %%
from mpl_toolkits.basemap import Basemap
import matplotlib.pyplot as plt
from pylab import rcParams
# %matplotlib inline
rcParams['figure.figsize'] = (14,10)

my_map = Basemap(projection='merc',
            resolution = 'l', area_thresh = 1000.0,
            llcrnrlon=llon, llcrnrlat=llat, #min longitude (llcrnrlon) and latitude (llcrnrlat)
            urcrnrlon=ulon, urcrnrlat=ulat) #max longitude (urcrnrlon) and latitude (urcrnrlat)

my_map.drawcoastlines()
my_map.drawcountries()
#my_map.drawmapboundary()
my_map.fillcontinents(color = 'white', alpha = 0.3)
my_map.shadedrelief()

# To create a color map
colors = plt.get_cmap('jet')(np.linspace(0.0, 1.0, clusterNum))



#Visualization1
for clust_number in set(labels):
    c=(([0.4,0.4,0.4]) if clust_number == -1 else colors[np.int(clust_number)])
    clust_set = pdf[pdf.Clus_Db == clust_number]                    
    my_map.scatter(clust_set.xm, clust_set.ym, color =c,  marker='o', s= 20, alpha = 0.85)
    if clust_number != -1:
        cenx=np.mean(clust_set.xm) 
        ceny=np.mean(clust_set.ym) 
        plt.text(cenx,ceny,str(clust_number), fontsize=25, color='red',)
        print ("Cluster "+str(clust_number)+', Avg Temp: '+ str(np.mean(clust_set.Tm)))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-22-814b2feba22e> in <module>
# ----> 1 from mpl_toolkits.basemap import Basemap
#       2 import matplotlib.pyplot as plt
#       3 from pylab import rcParams
#       4 get_ipython().run_line_magic('matplotlib', 'inline')
#       5 rcParams['figure.figsize'] = (14,10)
#
# ~\Anaconda3\lib\site-packages\mpl_toolkits\basemap\__init__.py in <module>
#     150
#     151 # create dictionary that maps epsg codes to Basemap kwargs.
# --> 152 pyproj_datadir = os.environ['PROJ_LIB']
#     153 epsgf = open(os.path.join(basemap_datadir,'epsg'))
#     154 epsg_dict={}
#
# ~\Anaconda3\lib\os.py in __getitem__(self, key)
#     676         except KeyError:
#     677             # raise KeyError with the original key value
# --> 678             raise KeyError(key) from None
#     679         return self.decodevalue(value)
#     680
#
# KeyError: 'PROJ_LIB'

# %% [markdown]
# ## Want to learn more?
#
# IBM SPSS Modeler is a comprehensive analytics platform that has many machine learning algorithms. It has been designed to bring predictive intelligence to decisions made by individuals, by groups, by systems – by your enterprise as a whole. A free trial is available through this course, available here: [SPSS Modeler](http://cocl.us/ML0101EN-SPSSModeler).
#
# Also, you can use Watson Studio to run these notebooks faster with bigger datasets. Watson Studio is IBM's leading cloud solution for data scientists, built by data scientists. With Jupyter notebooks, RStudio, Apache Spark and popular libraries pre-packaged in the cloud, Watson Studio enables data scientists to collaborate on their projects without having to install anything. Join the fast-growing community of Watson Studio users today with a free account at [Watson Studio](https://cocl.us/ML0101EN_DSX)
#
# ### Thanks for completing this lesson!
#
# Notebook created by: <a href = "https://ca.linkedin.com/in/saeedaghabozorgi">Saeed Aghabozorgi</a>
#
# <hr>
# Copyright &copy; 2018 [Cognitive Class](https://cocl.us/DX0108EN_CC). This notebook and its source code are released under the terms of the [MIT License](https://bigdatauniversity.com/mit-license/).​
